# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
data = pd.read_csv('mlb 1972-2021.csv')

# %% [markdown]
# # Dataset Sample

# %%
data.head()
# Out:
#                   Tm  Year  #Bat  BatAge    G         PA         AB   R/G  \
# 0     Atlanta Braves  1972    36    27.2  155  38.316129  34.051613  4.05
# 1  Baltimore Orioles  1972    32    28.7  154  36.857143  32.649351  3.37
# 2     Boston Red Sox  1972    38    28.9  155  37.883871  33.600000  4.13
# 3  California Angels  1972    40    29.1  155  36.387097  33.322581  2.93
# 4       Chicago Cubs  1972    41    30.0  156  38.147436  33.634615  4.39
#
#           H        2B  ...        Inn         Ch         PO          A  \
# 0  8.793548  1.200000  ...  79.980645  38.193548  26.651613  10.535484
# 1  7.487013  1.253247  ...  80.162338  38.090909  26.707792  10.733766
# 2  8.316129  1.477419  ...  80.283871  37.967742  26.741935  10.387097
# 3  8.058065  1.103226  ...  79.993548  37.761290  26.658065  10.367742
# 4  8.628205  1.320513  ...  80.692308  39.852564  26.897436  12.108974
#
#           E        DP   Fld%  Rtot  Rtot/yr   W-L%
# ...

# %% [markdown]
# # Null Values and Data Types

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1396 entries, 0 to 1395
# Data columns (total 74 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tm       1396 non-null   object
#  1   Year     1396 non-null   int64
#  2   #Bat     1396 non-null   int64
#  3   BatAge   1396 non-null   float64
#  4   G        1396 non-null   int64
#  5   PA       1396 non-null   float64
#  6   AB       1396 non-null   float64
#  7   R/G      1396 non-null   float64
#  8   H        1396 non-null   float64
#  9   2B       1396 non-null   float64
#  10  3B       1396 non-null   float64
#  11  HR       1396 non-null   float64
#  12  RBI      1396 non-null   float64
#  13  SB       1396 non-null   float64
#  14  CS       1396 non-null   float64
#  15  BB       1396 non-null   float64
#  16  SO       1396 non-null   float64
#  17  BA       1396 non-null   float64
#  18  OBP      1396 non-null   float64
#  19  SLG      1396 non-null   float64
# ...

# %%
data1 = data.iloc[:, 2:20]
data2 = data.iloc[:, 20:38]
data3 = data.iloc[:, 38:56]
data4 = data.iloc[:, 56:74]

# %% [markdown]
# # Descriptive Statistics

# %%
data1.describe()
# Out:
#               #Bat       BatAge            G           PA           AB  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean     43.327364    28.509312   157.263610    38.291246    34.102335
# std       6.358546     1.355916    17.641248     0.744852     0.558596
# min      29.000000    24.600000    58.000000    34.672414    30.206897
# 25%      39.000000    27.600000   162.000000    37.803378    33.777778
# 50%      43.000000    28.400000   162.000000    38.271605    34.105264
# 75%      47.000000    29.400000   162.000000    38.759259    34.456790
# max      69.000000    33.500000   164.000000    40.805310    35.685185
#
#                R/G            H           2B           3B           HR  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean      4.485172     8.850655     1.650427     0.199784     0.958670
# std       0.541904     0.543952     0.225686     0.063854     0.264990
# ...

# %%
data2.describe()
# Out:
#                OPS         OPS+           TB          GDP          HBP  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean      0.730625    96.890401    13.776660     0.762923     0.286324
# std       0.043014     8.435980     1.210340     0.103909     0.113447
# min       0.581000    73.000000     9.480519     0.462963     0.055556
# 25%       0.702000    91.000000    12.962963     0.691358     0.197531
# 50%       0.729000    97.000000    13.740741     0.759259     0.276074
# 75%       0.760000   103.000000    14.570988     0.833333     0.358025
# max       0.851000   123.000000    17.481481     1.074074     0.866667
#
#                 SH           SF          IBB          LOB           #P  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean      0.339143     0.280600     0.271448     7.017325    21.138968
# std       0.146114     0.057008     0.103521     0.358768     5.615457
# ...

# %%
data3.describe()
# Out:
#                 IP          H_P            R           ER         HR_P  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean      8.929883     8.850774     4.485255     4.073573     0.958731
# std       0.103205     0.587103     0.568498     0.548064     0.229625
# min       8.155172     6.482759     2.792208     2.506494     0.363636
# 25%       8.875776     8.456790     4.074074     3.679012     0.788730
# 50%       8.932099     8.845679     4.428571     4.024691     0.956790
# 75%       8.994419     9.257002     4.864198     4.448707     1.117284
# max       9.228395    10.703704     6.808642     6.265432     1.882716
#
#               BB_P        IBB_P         SO_P        HBP_P           BK  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean      3.277165     0.271441     6.397652     0.286322     0.046991
# std       0.409062     0.118538     1.288096     0.107514     0.038974
# ...

# %%
data4.describe()
# Out:
#                SO9         SO/W        LOB_P         #Fld       RA/G_D  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean      6.450287     1.986956     7.017307    42.882521     4.485279
# std       1.316036     0.501934     0.356525     6.441729     0.568490
# min       3.600000     1.030000     5.883333    29.000000     2.790000
# 25%       5.500000     1.620000     6.790123    38.000000     4.070000
# 50%       6.300000     1.900000     7.012346    42.000000     4.430000
# 75%       7.300000     2.270000     7.235221    47.000000     4.860000
# max      11.000000     3.980000     8.302469    68.000000     6.810000
#
#             DefEff           GS         CG_D          Inn           Ch  \
# count  1396.000000  1396.000000  1396.000000  1396.000000  1396.000000
# mean      0.694830     9.000004     6.836770    80.381781    37.892459
# std       0.013138     0.003454     0.370187     0.927523     1.125900
# ...

# %% [markdown]
# # Histograms

# %% [markdown]
# Target Variable

# %%
data['W-L%'].hist()
plt.show()

# %% [markdown]
# All Features

# %%
data.iloc[:, 2:74].hist(bins=15, linewidth=1.0, edgecolor='black',
          xlabelsize=8, ylabelsize=8, figsize=(20,20), grid=False)
plt.show()

# %% [markdown]
# # Density Plots

# %%
data.iloc[:, 2:74].plot(kind='density', subplots=True, layout=(9,9), figsize=(25,25), sharex=False)
plt.show()

# %% [markdown]
# # Box and Whisker Plots (Features 1-36)

# %%
data.iloc[:, 2:38].plot(kind='box', subplots=True, layout=(6,6), figsize=(20,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# # Box and Whisker Plots (Features 37-72)

# %%
data.iloc[:, 38:74].plot(kind='box', subplots=True, layout=(6,6), figsize=(20,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
corr = data.corr()
corr
# Out:
#              Year      #Bat    BatAge         G        PA        AB       R/G  \
# Year     1.000000  0.693303  0.149742 -0.095741 -0.059896 -0.006964  0.229156
# #Bat     0.693303  1.000000  0.052410  0.084672 -0.100964 -0.051325  0.073113
# BatAge   0.149742  0.052410  1.000000  0.042033  0.273284  0.147370  0.302690
# G       -0.095741  0.084672  0.042033  1.000000  0.182479  0.261611 -0.030323
# PA      -0.059896 -0.100964  0.273284  0.182479  1.000000  0.768328  0.739050
# ...           ...       ...       ...       ...       ...       ...       ...
# DP      -0.226572 -0.176561 -0.026093  0.097294  0.156914  0.221374  0.065293
# Fld%     0.662649  0.345927  0.315960 -0.022547  0.085024  0.074563  0.267481
# Rtot     0.028927 -0.110778  0.049628 -0.000986  0.058317 -0.005053  0.135464
# Rtot/yr  0.030328 -0.107802  0.046793 -0.008103  0.054594 -0.013236  0.136939
# W-L%     0.000056 -0.211843  0.293747  0.002223  0.383295  0.151311  0.524087
#
# ...

# %%
fig = plt.figure(figsize=(14,14))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);
